# %%
import sys
import torch
import transformers

print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("Transformers:", transformers.__version__)
# Out:
# Python: 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]
# PyTorch: 2.13.0+cpu
# Transformers: 5.16.1

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

print("BLIP libraries are working!")
# Out:
# BLIP libraries are working!

# %%
processor = BlipProcessor.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

print("Model loaded successfully!")
# Out:
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Model loaded successfully!

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\tvisw\Generative AI Tasks

# %%
Image.open("Dog.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=824x546>

# %%
image = Image.open("Dog.png").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a corgy corgy corgy corgy corgy corgy corgy corgy corgy corg

# %%
Image.open("parrot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=542x357>

# %%
image = Image.open("parrot.png").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a green parrot perched on a tree branch

# %%
Image.open("car.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=885x537>

# %%
image = Image.open("Car.png").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a white bmw with a black rim parked on a road
